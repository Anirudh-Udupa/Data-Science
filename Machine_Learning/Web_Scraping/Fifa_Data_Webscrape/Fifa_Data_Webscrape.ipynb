# %%
import pandas as pd
import re
import requests
import urllib
from bs4 import BeautifulSoup

# %%
# Get basic players information for all players
base_url = "https://sofifa.com/players?offset="
columns = ['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special']
data = pd.DataFrame(columns = columns)

proxies = {
  'http': 'www-proxy.us.oracle.com:80',
  'https': 'www-proxy.us.oracle.com:80',
}
#for offset in range(0, 300):
url = base_url + str(1 * 61)
source_code = requests.get(url,proxies=proxies)
plain_text = source_code.text
soup = BeautifulSoup(plain_text, 'html.parser')

type(soup)
# Out:
# bs4.BeautifulSoup

# %%
# Get basic players information for all players
base_url = "https://sofifa.com/players?offset="
columns = ['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special']
data = pd.DataFrame(columns = columns)
proxies = {
  'http': 'www-proxy.us.oracle.com:80',
  'https': 'www-proxy.us.oracle.com:80',
}

for offset in range(0,1):
    url = base_url + str(offset * 61)
    source_code = requests.get(url,proxies=proxies)
    plain_text = source_code.text
    soup = BeautifulSoup(plain_text, 'html.parser')
    table_body = soup.find('tbody')
    for row in table_body.findAll('tr'):
        td = row.findAll('td')
        picture = td[0].find('img').get('data-src')
        pid = td[0].find('img').get('id')
        nationality = td[1].find('a').get('title')
        flag_img = td[1].find('img').get('data-src')
        name = td[1].findAll('a')[1].text
        age = td[2].find('div').text.strip()
        overall = td[3].text.strip()
        potential = td[4].text.strip()
        club = td[5].find('a').text
        club_logo = td[5].find('img').get('data-src')
        value = td[6].text.strip()
        wage = td[7].text.strip()
        special = td[8].text.strip()
        player_data = pd.DataFrame([[pid, name, age, picture, nationality, flag_img, overall, potential, club, club_logo, value, wage, special]])
        player_data.columns = columns
        data = data.append(player_data, ignore_index=True)
data = data.drop_duplicates()

# Get detailed player information from player page
detailed_columns = ['Preferred Foot', 'International Reputation', 'Weak Foot', 'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position', 'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until', 'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes', 'ID']
detailed_data = pd.DataFrame(index = range(0, 61), columns = detailed_columns)
detailed_data.ID = data.ID.values

player_data_url = 'https://sofifa.com/player/'
for id in data.ID:
    url = player_data_url + str(id)
    source_code = requests.get(url,proxies=proxies)
    plain_text = source_code.text
    soup = BeautifulSoup(plain_text, 'html.parser')
    skill_map = {}
    columns = soup.find('div', {'class': 'teams'}).find('div', {'class': 'columns'}).findAll('div', {'class': 'column col-4'})
    for column in columns:
        skills = column.findAll('li')
        for skill in skills:
            if(skill.find('label') != None):
                label = skill.find('label').text
                value = skill.text.replace(label, '').strip()
                skill_map[label] = value
    meta_data = soup.find('div', {'class': 'meta'}).text.split(' ')
    length = len(meta_data)
    weight = meta_data[length - 1]
    height = meta_data[length - 2].split('\'')[0] + '\'' + meta_data[length - 2].split('\'')[1].split('\"')[0]
    skill_map["Height"] = height
    skill_map['Weight'] = weight
    if('Position' in skill_map.keys()):
        if skill_map['Position'] in ('', 'RES', 'SUB'):
            skill_map['Position'] = soup.find('article').find('div', {'class': 'meta'}).find('span').text
        if(skill_map['Position'] != 'GK'):
            card_rows = soup.find('aside').find('div', {'class': 'card mb-2'}).find('div', {'class': 'card-body'}).findAll('div', {'class': 'columns'})
            for c_row in card_rows:
                attributes = c_row.findAll('div', {'class': re.compile('column col-sm-2 text-center')})
                for attribute in attributes:
                    if(attribute.find('div')):
                        name = ''.join(re.findall('[a-zA-Z]', attribute.text))
                        value = attribute.text.replace(name, '').strip()
                        skill_map[str(name)] = value
    sections = soup.find('article').findAll('div', {'class': 'mb-2'})[1:3]
    first = sections[0].findAll('div', {'class': 'column col-4'})
    second = sections[1].findAll('div', {'class': 'column col-4'})[:-1]
    sections = first + second
    for section in sections:
        items = section.find('ul').findAll('li')
        for item in items:
            value = int(re.findall(r'\d+', item.text)[0])
            name = ''.join(re.findall('[a-zA-Z]*', item.text))
            skill_map[str(name)] = value
    for key, value in skill_map.items():
        detailed_data.loc[detailed_data.ID == id, key] = value

full_data = pd.merge(data, detailed_data, how = 'inner', on = 'ID')
print(full_data)
#full_data.to_csv('data.csv', encoding='utf-8-sig')
# Out:
#         ID               Name Age  \
# 0   158023           L. Messi  31
# 1    20801  Cristiano Ronaldo  33
# 2   190871          Neymar Jr  26
# 3   193080             De Gea  27
# 4   192985       K. De Bruyne  27
# 5   183277          E. Hazard  27
# 6   177003          L. Modrić  32
# 7   176580          L. Suárez  31
# 8   202126            H. Kane  24
# 9   200389           J. Oblak  25
# 10  188545     R. Lewandowski  29
# 11  182493           D. Godín  32
# 12  168542        David Silva  32
# 13  155862       Sergio Ramos  32
# 14  138956       G. Chiellini  33
# 15  215914           N. Kanté  27
# 16  211110          P. Dybala  24
# 17  209331           M. Salah  26
# 18  194765       A. Griezmann  27
# 19  192448      M. ter Stegen  26
# 20  192119        T. Courtois  26
# 21  189511    Sergio Busquets  29
# 22  182521           T. Kroos  28
# 23  179813          E. Cavani  31
# 24  167495           M. Neuer  32
# 25  153079          S. Agüero  30
# 26  231747          K. Mbappé  19
# 27  203376        V. van Dijk  26
# 28  201024       K. Koulibaly  27
# 29  198219         L. Insigne  27
# ..     ...                ...  ..
# 31  190460         C. Eriksen  26
# 32  188567      P. Aubameyang  29
# 33  188350            M. Reus  29
# 34  178603         M. Hummels  29
# 35  167948          H. Lloris  31
# 36  164240       Thiago Silva  33
# 37  162835      S. Handanovič  33
# 38  152729              Piqué  31
# 39  212831            Alisson  25
# 40  205600          S. Umtiti  24
# 41  202652        R. Sterling  23
# 42  201399          M. Icardi  25
# 43  200145           Casemiro  26
# 44  198710       J. Rodríguez  26
# 45  197781               Isco  26
# 46  193041           K. Navas  31
# 47  192387        C. Immobile  28
# 48  189509             Thiago  27
# 49  189332         Jordi Alba  29
# 50  189242           Coutinho  26
# 51  184087    T. Alderweireld  29
# 52  176676            Marcelo  30
# 53  175943         D. Mertens  31
# 54  173731            G. Bale  28
# 55  172871      J. Vertonghen  31
# 56  168651         I. Rakitić  30
# 57  167664         G. Higuaín  30
# 58  135507        Fernandinho  33
# 59    1179          G. Buffon  40
# 60  232363        M. Škriniar  23
#
#                                              Photo  Nationality  \
# 0   https://cdn.sofifa.org/players/4/19/158023.png    Argentina
# 1    https://cdn.sofifa.org/players/4/19/20801.png     Portugal
# 2   https://cdn.sofifa.org/players/4/19/190871.png       Brazil
# 3   https://cdn.sofifa.org/players/4/19/193080.png        Spain
# 4   https://cdn.sofifa.org/players/4/19/192985.png      Belgium
# 5   https://cdn.sofifa.org/players/4/19/183277.png      Belgium
# 6   https://cdn.sofifa.org/players/4/19/177003.png      Croatia
# 7   https://cdn.sofifa.org/players/4/19/176580.png      Uruguay
# 8   https://cdn.sofifa.org/players/4/19/202126.png      England
# 9   https://cdn.sofifa.org/players/4/19/200389.png     Slovenia
# 10  https://cdn.sofifa.org/players/4/19/188545.
# 52   https://cdn.sofifa.org/flags/54.png      87        87
# 53    https://cdn.sofifa.org/flags/7.png      87        87
# 54   https://cdn.sofifa.org/flags/50.png      87        87
# 55    https://cdn.sofifa.org/flags/7.png      87        87
# 56   https://cdn.sofifa.org/flags/10.png      87        87
# 57   https://cdn.sofifa.org/flags/52.png      87        87
# 58   https://cdn.sofifa.org/flags/54.png      87        87
# 59   https://cdn.sofifa.org/flags/27.png      87        87
# 60   https://cdn.sofifa.org/flags/43.png      86        93
#
#                    Club                                     Club Logo  \
# 0          FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png
# 1              Juventus   https://cdn.sofifa.org/teams/2/light/45.png
# 2   Paris Saint-Germain   https://cdn.sofifa.org/teams/2/light/73.png
# 3     Manchester United   https://cdn.sofifa.org/teams/2/light/11.png
# 4       Manchester City   https://cdn.sofifa.org/teams/2/light/10.png
# 5               Chelsea    https://cdn.sofifa.org/teams/2/light/5.png
# 6           Real Madrid  https://cdn.sofifa.org/teams/2/light/243.png
# 7          FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png
# 8     Tottenham Hotspur   https://cdn.sofifa.org/teams/2/light/18.png
# 9       Atlético Madrid  https://cdn.sofifa.org/teams/2/light/240.png
# 10    FC Bayern München   https://cdn.sofifa.org/teams/2/light/21.png
# 11      Atlético Madrid  https://cdn.sofifa.org/teams/2/light/240.png
# 12      Manchester City   https://cdn.sofifa.org/teams/2/light/10.png
# 13          Real Madrid  https://cdn.sofifa.org/teams/2/light/243.png
# 14             Juventus   https://cdn.sofifa.org/teams/2/light/45.png
# 15              Chelsea    https://cdn.sofifa.org/teams/2/light/5.png
# 16             Juventus   https://cdn.sofifa.org/teams/2/light/45.png
# 17            Liverpool    https://cdn.sofifa.org/teams/2/light/9.png
# 18      Atlético Madrid  https://cdn.sofifa.org/teams/2/light/240.png
# 19         FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png
# 20          Real Madrid  https://cdn.sofifa.org/teams/2/light/243.png
# 21         FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png
# 22          Real Madrid  https://cdn.sofifa.org/teams/2/light/243.png
# 23  Paris Saint-Germain   https://cdn.sofifa.org/teams/2/light/73.png
# 24    FC Bayern München   https://cdn.sofifa.org/teams/2/light/21.png
# 25      Manchester City   https://cdn.sofifa.org/teams/2/light/10.png
# 26  Paris Saint-Germain   https://cdn.sofifa.org/teams/2/light/73.png
# 27            Liverpool    https://cdn.sofifa.org/teams/2/light/9.png
# 28               Napoli   https://cdn.sofifa.org/teams/2/light/48.png
# 29               Napoli   https://cdn.sofifa.org/teams/2/light/48.png
# ..                  ...                                           ...
# 31    Tottenham Hotspur   https://cdn.sofifa.org/teams/2/light/18.png
# 32              Arsenal    https://cdn.sofifa.org/teams/2/light/1.png
# 33    Borussia Dortmund   https://cdn.sofifa.org/teams/2/light/22.png
# 34    FC Bayern München   https://cdn.sofifa.org/teams/2/light/21.png
# 35    Tottenham Hotspur   https://cdn.sofifa.org/teams/2/light/18.png
# 36  Paris Saint-Germain   https://cdn.sofifa.org/teams/2/light/73.png
# 37                Inter   https://cdn.sofifa.org/teams/2/light/44.png
# 38         FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png
# 39            Liverpool    https://cdn.sofifa.org/teams/2/light/9.png
# 40         FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png
# 41      Manchester City   https://cdn.sofifa.org/teams/2/light/10.png
# 42                Inter   https://cdn.sofifa.org/teams/2/light/44.png
# 43          Real Madrid  https://cdn.sofifa.org/teams/2/light/243.png
# 44    FC Bayern München   https://cdn.sofifa.org/teams/2/light/21.png
# 45          Real Madrid  https://cdn.sofifa.org/teams/2/light/243.png
# 46          Real Madrid  https://cdn.sofifa.org/teams/2/light/243.png
# 47                Lazio   https://cdn.sofifa.org/teams/2/light/46.png
# 48    FC Bayern München   https://cdn.sofifa.org/teams/2/light/21.png
# 49         FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png
# 50         FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png
# 51    Tottenham Hotspur   https://cdn.sofifa.org/teams/2/light/18.png
# 52          Real Madrid  https://cdn.sofifa.org/teams/2/light/243.png
# 53               Napoli   https://cdn.sofifa.org/teams/2/light/48.png
# 54          Real Madrid  https://cdn.sofifa.org/teams/2/light/243.png
# 55    Tottenham Hotspur   https://cdn.sofifa.org/teams/2/light/18.png
# 56         FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png
# 57              Chelsea    https://cdn.sofifa.org/teams/2/light/5.png
# 58      Manchester City   https://cdn.sofifa.org/teams/2/light/10.png
# 59  Paris Saint-Germain   https://cdn.sofifa.org/teams/2/light/73.png
# 60                Inter   https://cdn.sofifa.org/teams/2/light/44.png
#
#         ...       Composure Marking StandingTackle SlidingTackle GKDiving  \
# 0       ...              96      33             28            26        6
# 1       ...              95      28             31            23        7
# 2       ...              94      27             24            33        9
# 3       ...              70      25             21            13       90
# 4       ...              90      68             58            51       15
# 5       ...              91      34             27            22       11
# 6       ...              92      68             76            73       13
# 7       ...              85      62             45            38       27
# 8       ...              91      56             36            38        8
# 9       ...              70      27             12            18       86
# 10      ...              86      34             42            19       15
# 11      ...              82      90             89            89        6
# 12      ...              93      59             53            29        6
# 13      ...              84      87             89            90       11
# 14      ...              84      94             93            90        3
# 15      ...              85      90             91            85       15
# 16      ...              84      23             20            20        5
# 17      ...              91      38             43            41       14
# 18      ...              89      59             54            48       14
# 19      ...              70      25             13            10       88
# 20      ...              66      20             18            16       85
# 21      ...              93      90             86            80        5
# 22      ...              88      72             74            66       10
# 23      ...              82      52             45            39       12
# 24      ...              70      17             10            11       90
# 25      ...              90      30             20            12       13
# 26      ...              86      34             34            32       13
# 27      ...              87      90             89            84       13
# 28      ...              80      91             88            87        7
# 29      ...              83      51             24            22        8
# ..      ...             ...     ...            ...           ...      ...
# 31      ...              88      59             57            22        9
# 32      ...              86      27             25            36        6
# 33      ...              85      49             36            45       12
# 34      ...              91      88             90            88       15
# 35      ...              65      29             10            18       88
# 36      ...              86      88             89            85        9
